# %% [markdown]
# # CLI - Human Protein Atlas
#
# This notebook contains example usage of the pyhpa cli.

# %%
import pandas as pd
# %run -m ipy_logging

# %%
# !python ../../pyhpa/script/gene_selector.py --output /tmp/genes.csv

# %%
pd.read_csv('/tmp/genes.csv').head()
# Out:
#       Gene                                       Gene synonym  \
# 0     CFTR  ABC35, ABCC7, CF, CFTR/MRP, dJ760C5.1, MRP7, T...
# 1  CYP51A1         CP51, CYP51, CYPL1, LDM, P450-14DM, P450L1
# 2     M6PR                                                NaN
# 3     TFPI                              EPI, LACI, TFI, TFPI1
# 4  SLC25A5                                  2F1, ANT2, T2, T3
#
#            Ensembl                                   Gene description  \
# 0  ENSG00000001626  Cystic fibrosis transmembrane conductance regu...
# 1  ENSG00000001630  Cytochrome P450, family 51, subfamily A, polyp...
# 2  ENSG00000003056    Mannose-6-phosphate receptor (cation dependent)
# 3  ENSG00000003436  Tissue factor pathway inhibitor (lipoprotein-a...
# 4  ENSG00000005022  Solute carrier family 25 (mitochondrial carrie...
#
#   Chromosome             Position                   Evidence  \
# 0          7  117465784-117715971  Evidence at protein level
# ...
